# %%
print("hello")
# Out:
# hello

# %% [markdown]
# 문서를 작성합니다.
# # 제목 1
# ## 제목 2
# ### 제목 3
# - 아이템 1
# - 아이템 2
# - 아이템 3
#    - 아이템 4
#
# ipynb: interactive python notebook

# %% [markdown]
# 문서를 작성합니다.
